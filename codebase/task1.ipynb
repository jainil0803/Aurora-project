# %% [markdown]
# # Extracting KB

# %%
# %pip install langchain langgraph langchain-community ollama pydantic scikit-learn pandas matplotlib seaborn numpy langchain-ollama chromadb langchain-text-splitters python-dotenv

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import os
import json
from typing import TypedDict, Dict, Any, List
from langgraph.graph import StateGraph, END
from langchain_ollama import ChatOllama
from langchain_core.messages import SystemMessage, HumanMessage
from pydantic import BaseModel, Field
from langchain_core.output_parsers import JsonOutputParser
from dotenv import load_dotenv

# Load environment variables from .env file
load_dotenv()

# --- File paths ---
KB_PATH = "./input/KB.md"
PROMPTS_PATH = "./prompts/prompts.json"

# --- LLM configuration ---
# Temperature 0 ensures deterministic, reproducible extractions
ollama_model = "llama3.2"
ollama_model_temperature = 0

# --- Ollama connection ---
# Set OLLAMA_MODE in .env to "web" (ngrok tunnel) or "local" (default: 127.0.0.1:11434)
_mode = os.getenv("OLLAMA_MODE", "local")
OLLAMA_BASE_URL = (
    os.getenv("OLLAMA_WEB_URL", "https://unsympathizing-censorian-buena.ngrok-free.dev/")
    if _mode == "web"
    else os.getenv("OLLAMA_LOCAL_URL", "http://127.0.0.1:11434")
)
print(f"Ollama mode: {_mode.upper()} → {OLLAMA_BASE_URL}")


def load_json(path: str) -> Dict:
    """Load and return parsed JSON from the given file path."""
    with open(path, "r", encoding="utf-8") as f:
        return json.load(f)
# Out:
# Requirement already satisfied: langchain in d:\2688_project_aurora\.venv\lib\site-packages (1.2.10)
# Requirement already satisfied: langgraph in d:\2688_project_aurora\.venv\lib\site-packages (1.0.10)
# Requirement already satisfied: langchain-community in d:\2688_project_aurora\.venv\lib\site-packages (0.4.1)
# Requirement already satisfied: ollama in d:\2688_project_aurora\.venv\lib\site-packages (0.6.1)
# Requirement already satisfied: pydantic in d:\2688_project_aurora\.venv\lib\site-packages (2.12.5)
# Requirement already satisfied: scikit-learn in d:\2688_project_aurora\.venv\lib\site-packages (1.8.0)
# Requirement already satisfied: pandas in d:\2688_project_aurora\.venv\lib\site-packages (3.0.1)
# Requirement already satisfied: matplotlib in d:\2688_project_aurora\.venv\lib\site-packages (3.10.8)
# Requirement already satisfied: seaborn in d:\2688_project_aurora\.venv\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy in d:\2688_project_aurora\.venv\lib\site-packages (2.4.3)
# Requirement already satisfied: langchain-ollama in d:\2688_project_aurora\.venv\lib\site-packages (1.0.1)
# Requirement already satisfied: chromadb in d:\2688_project_aurora\.venv\lib\site-packages (1.5.5)
# Requirement already satisfied: langchain-text-splitters in d:\2688_project_aurora\.venv\lib\site-packages (1.1.1)
# Requirement already satisfied: python-dotenv in d:\2688_project_aurora\.venv\lib\site-packages (1.2.2)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.10 in d:\2688_project_aurora\.venv\lib\site-packages (from langchain) (1.2.18)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in d:\2688_project_aurora\.venv\lib\site-packages (from langgraph) (4.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.8 in d:\2688_project_aurora\.venv\lib\site-packages (from langgraph) (1.0.8)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in d:\2688_project_aurora\.venv\lib\site-packages (from langgraph) (0.3.10)
# Requirement already satisfied: xxhash>=3.5.0 in d:\2688_project_aurora\.venv\lib\site-packages (from langgraph) (3.6.0)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in d:\2688_project_aurora\.venv\lib\site-packages (from langchain-community) (1.0.2)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in d:\2688_project_aurora\.venv\lib\site-packages (from langchain-community) (2.0.48)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in d:\2688_project_aurora\.venv\lib\site-packages (from langchain-community) (2.32.5)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in d:\2688_project_aurora\.venv\lib\site-packages (from langchain-community) (6.0.3)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in d:\2688_project_aurora\.venv\lib\site-packages (from langchain-community) (3.13.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in d:\2688_project_aurora\.venv\lib\site-packages (from langchain-community) (9.1.4)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in d:\2688_project_aurora\.venv\lib\site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in d:\2688_project_aurora\.venv\lib\site-packages (from langchain-community) (2.13.1)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in d:\2688_project_aurora\.venv\lib\site-packages (from langchain-community) (0.7.16)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in d:\2688_project_aurora\.venv\lib\site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: httpx>=0.27 in d:\2688_project_aurora\.venv\lib\site-packages (from ollama) (0.28.1)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\2688_project_aurora\.venv\lib\site-packages (from pydantic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in d:\2688_project_aurora\.venv\lib\site-packages (from pydantic) (2.41.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in d:\2688_project_aurora\.venv\lib\site-packages (from pydantic) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in d:\2688_project_aurora\.venv\lib\site-packages (from pydantic) (0.4.2)
# Requirement already satisfied: scipy>=1.10.0 in d:\2688_project_aurora\.venv\lib\site-packages (from scikit-learn) (1.17.1)
# Requirement already satisfied: joblib>=1.3.0 in d:\2688_project_aurora\.venv\lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in d:\2688_project_aurora\.venv\lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\2688_project_aurora\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in d:\2688_project_aurora\.venv\lib\site-packages (from pandas) (2025.3)
# Requirement already satisfied: contourpy>=1.0.1 in d:\2688_project_aurora\.venv\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in d:\2688_project_aurora\.venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\2688_project_aurora\.venv\lib\site-packages (from matplotlib) (4.62.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\2688_project_aurora\.venv\lib\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in d:\2688_project_aurora\.venv\lib\site-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=8 in d:\2688_project_aurora\.venv\lib\site-packages (from matplotlib) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in d:\2688_project_aurora\.venv\lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: build>=1.0.3 in d:\2688_project_aurora\.venv\lib\site-packages (from chromadb) (1.4.0)
# Requirement already satisfied: pybase64>=1.4.1 in d:\2688_project_aurora\.venv\lib\site-packages (from chromadb) (1.4.3)
# Requirement already satisfied: uvicorn>=0.18.3 in d:\2688_project_aurora\.venv\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.41.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in d:\2688_project_aurora\.venv\lib\site-packages (from chromadb) (1.24.3)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in d:\2688_project_aurora\.venv\lib\site-packages (from chromadb) (1.40.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in d:\2688_project_aurora\.venv\lib\site-packages (from chromadb) (1.40.0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in d:\2688_project_aurora\.venv\lib\site-packages (from chromadb) (1.40.0)
# Requirement already satisfied: tokenizers>=0.13.2 in d:\2688_project_aurora\.venv\lib\site-packages (from chromadb) (0.22.2)
# Requirement already satisfied: pypika>=0.48.9 in d:\2688_project_aurora\.venv\lib\site-packages (from chromadb) (0.51.1)
# Requirement already satisfied: tqdm>=4.65.0 in d:\2688_project_aurora\.venv\lib\site-packages (from chromadb) (4.67.3)
# Requirement already satisfied: overrides>=7.3.1 in d:\2688_project_aurora\.venv\lib\site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in d:\2688_project_aurora\.venv\lib\site-packages (from chromadb) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in d:\2688_project_aurora\.venv\lib\site-packages (from chromadb) (1.78.0)
# Requirement already satisfied: bcrypt>=4.0.1 in d:\2688_project_aurora\.venv\lib\site-packages (from chromadb) (5.0.0)
# Requirement already satisfied: typer>=0.9.0 in d:\2688_project_aurora\.venv\lib\site-packages (from chromadb) (0.24.1)
# Requirement already satisfied: kubernetes>=28.1.0 in d:\2688_project_aurora\.venv\lib\site-packages (from chromadb) (35.0.0)
# Requirement already satisfied: mmh3>=4.0.1 in d:\2688_project_aurora\.venv\lib\site-packages (from chromadb) (5.2.1)
# Requirement already satisfied: orjson>=3.9.12 in d:\2688_project_aurora\.venv\lib\site-packages (from chromadb) (3.11.7)
# Requirement already satisfied: rich>=10.11.0 in d:\2688_project_aurora\.venv\lib\site-packages (from chromadb) (14.3.3)
# Requirement already satisfied: jsonschema>=4.19.0 in d:\2688_project_aurora\.venv\lib\site-packages (from chromadb) (4.26.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in d:\2688_project_aurora\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in d:\2688_project_aurora\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in d:\2688_project_aurora\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in d:\2688_project_aurora\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in d:\2688_project_aurora\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in d:\2688_project_aurora\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in d:\2688_project_aurora\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.23.0)
# Requirement already satisfied: pyproject_hooks in d:\2688_project_aurora\.venv\lib\site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: colorama in d:\2688_project_aurora\.venv\lib\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in d:\2688_project_aurora\.venv\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in d:\2688_project_aurora\.venv\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (0.9.0)
# Requirement already satisfied: anyio in d:\2688_project_aurora\.venv\lib\site-packages (from httpx>=0.27->ollama) (4.12.1)
# Requirement already satisfied: certifi in d:\2688_project_aurora\.venv\lib\site-packages (from httpx>=0.27->ollama) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in d:\2688_project_aurora\.venv\lib\site-packages (from httpx>=0.27->ollama) (1.0.9)
# Requirement already satisfied: idna in d:\2688_project_aurora\.venv\lib\site-packages (from httpx>=0.27->ollama) (3.11)
# Requirement already satisfied: h11>=0.16 in d:\2688_project_aurora\.venv\lib\site-packages (from httpcore==1.*->httpx>=0.27->ollama) (0.16.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in d:\2688_project_aurora\.venv\lib\site-packages (from jsonschema>=4.19.0->chromadb) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in d:\2688_project_aurora\.venv\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in d:\2688_project_aurora\.venv\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.30.0)
# Requirement already satisfied: six>=1.9.0 in d:\2688_project_aurora\.venv\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.17.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in d:\2688_project_aurora\.venv\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.9.0)
# Requirement already satisfied: requests-oauthlib in d:\2688_project_aurora\.venv\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: urllib3!=2.6.0,>=1.24.2 in d:\2688_project_aurora\.venv\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.6.3)
# Requirement already satisfied: durationpy>=0.7 in d:\2688_project_aurora\.venv\lib\site-packages (from kubernetes>=28.1.0->chromadb) (0.10)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in d:\2688_project_aurora\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (1.33)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in d:\2688_project_aurora\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (0.14.1)
# Requirement already satisfied: ormsgpack>=1.12.0 in d:\2688_project_aurora\.venv\lib\site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph) (1.12.2)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in d:\2688_project_aurora\.venv\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in d:\2688_project_aurora\.venv\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.25.0)
# Requirement already satisfied: flatbuffers in d:\2688_project_aurora\.venv\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (25.12.19)
# Requirement already satisfied: protobuf in d:\2688_project_aurora\.venv\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (6.33.5)
# Requirement already satisfied: sympy in d:\2688_project_aurora\.venv\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (1.14.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in d:\2688_project_aurora\.venv\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (8.7.1)
# Requirement already satisfied: googleapis-common-protos~=1.57 in d:\2688_project_aurora\.venv\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.73.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.40.0 in d:\2688_project_aurora\.venv\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.40.0)
# Requirement already satisfied: opentelemetry-proto==1.40.0 in d:\2688_project_aurora\.venv\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.40.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.61b0 in d:\2688_project_aurora\.venv\lib\site-packages (from opentelemetry-sdk>=1.2.0->chromadb) (0.61b0)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\2688_project_aurora\.venv\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.4.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in d:\2688_project_aurora\.venv\lib\site-packages (from rich>=10.11.0->chromadb) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in d:\2688_project_aurora\.venv\lib\site-packages (from rich>=10.11.0->chromadb) (2.19.2)
# Requirement already satisfied: greenlet>=1 in d:\2688_project_aurora\.venv\lib\site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community) (3.3.2)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in d:\2688_project_aurora\.venv\lib\site-packages (from tokenizers>=0.13.2->chromadb) (1.6.0)
# Requirement already satisfied: click>=8.2.1 in d:\2688_project_aurora\.venv\lib\site-packages (from typer>=0.9.0->chromadb) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in d:\2688_project_aurora\.venv\lib\site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in d:\2688_project_aurora\.venv\lib\site-packages (from typer>=0.9.0->chromadb) (0.0.4)
# Requirement already satisfied: httptools>=0.6.3 in d:\2688_project_aurora\.venv\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.7.1)
# Requirement already satisfied: watchfiles>=0.20 in d:\2688_project_aurora\.venv\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.1.1)
# Requirement already satisfied: websockets>=10.4 in d:\2688_project_aurora\.venv\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (16.0)
# Requirement already satisfied: filelock>=3.10.0 in d:\2688_project_aurora\.venv\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.25.1)
# Requirement already satisfied: fsspec>=2023.5.0 in d:\2688_project_aurora\.venv\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2026.2.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.3.2 in d:\2688_project_aurora\.venv\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (1.3.2)
# Requirement already satisfied: zipp>=3.20 in d:\2688_project_aurora\.venv\lib\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.23.0)
# Requirement already satisfied: jsonpointer>=1.9 in d:\2688_project_aurora\.venv\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.10->langchain) (3.0.0)
# Requirement already satisfied: mdurl~=0.1 in d:\2688_project_aurora\.venv\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in d:\2688_project_aurora\.venv\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community) (1.1.0)
# Requirement already satisfied: oauthlib>=3.0.0 in d:\2688_project_aurora\.venv\lib\site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb) (3.3.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in d:\2688_project_aurora\.venv\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.
# Ollama mode: WEB → https://unsympathizing-censorian-buena.ngrok-free.dev
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## Langgraph setup

# %%
from pydantic import BaseModel, Field
from typing import List, Any
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_ollama import OllamaEmbeddings
from langchain_community.vectorstores import Chroma

# --- 1. DEFINE STRICT PYDANTIC SCHEMAS (UPDATED TO MATCH IMAGE) ---

class CompanyNorthStar(BaseModel):
    inferred_north_star: str = Field(description="The primary inferred North Star metric")
    justification: str = Field(description="The justification for choosing this metric")
    measurable_proxy: str = Field(description="The measurable proxy for the North Star")

class HookTaxonomy(BaseModel):
    hook_name: str
    description: str

class AllowedToneHookMatrix(BaseModel):
    allowed_tones: List[str]
    disallowed_tones: List[str]
    hook_taxonomy: List[HookTaxonomy] = Field(description="Taxonomy of behavioral hooks")

class FeatureMapping(BaseModel):
    feature_name: str
    lifecycle_stage: str = Field(description="The specific lifecycle stage this feature targets")
    outcome_mapping: str = Field(description="The desired outcome mapping for this feature")

class FeatureGoalMap(BaseModel):
    features: List[FeatureMapping]

# --- 2. HARDCODED PROMPTS & SCHEMA MAPPING ---

PROMPTS = {
    "company_north_star": {
        "system": "You are a product analytics expert. Extract the North Star metric details based on the provided Knowledge Base.",
        "user": "Extract the inferred north star metric, its justification, and a measurable proxy from the following KB:\n\nKB:\n{kb}",
        "schema": CompanyNorthStar
    },
    "allowed_tone_hook_matrix": {
        "system": "You are a behavioral design analyst. Extract tone rules and hook taxonomy based on the provided Knowledge Base.",
        "user": "Extract allowed tones, disallowed tones, and a complete hook taxonomy from the following KB:\n\nKB:\n{kb}",
        "schema": AllowedToneHookMatrix
    },
    "feature_goal_map": {
        "system": "You are a product goal alignment specialist. Extract goal mappings for the provided features based on the Knowledge Base.",
        "user": "For EACH of the following features, map it to a specific user lifecycle stage and its intended outcome mapping.\n\nFeatures to map:\n{features}\n\nUse this KB context to inform mappings:\n{kb}",
        "schema": FeatureGoalMap
    }
}

# --- 3. HARDCODED FEATURES (Extracted from CSV) ---
all_columns = [
    "user_id", "lifecycle_stage", "days_since_signup", "age_band", "region", 
    "sessions_last_7d", "exercises_completed_7d", "streak_current", "coins_balance", 
    "feature_ai_tutor_used", "feature_leaderboard_viewed", "feature_progress_checked", 
    "preferred_hour", "notif_open_rate_30d", "motivation_score", "gamification_propensity", 
    "ai_tutor_propensity", "leaderboard_propensity", "activation_score", "dominant_propensity", 
    "activation_level", "segment_id", "segment_name"
]
exclude = {'user_id', 'segment_id', 'segment_name', 'lifecycle_stage', 'activation_level', 'dominant_propensity'}
filtered_columns = [col for col in all_columns if col not in exclude]

FEATURES_STRING = "\n".join([f"{i+1}. {col}" for i, col in enumerate(filtered_columns)])

# --- 4. RAG CONFIGURATION ---
RAG_QUERIES = {
    "company_north_star":      "North Star metric company goal measurable proxy success indicator KPI",
    "allowed_tone_hook_matrix":"tone communication style allowed disallowed behavioral hooks hook taxonomy messaging",
    "feature_goal_map":        "product features lifecycle stage outcome goals user engagement mapping",
}
RAG_TOP_K = 5   # number of chunks retrieved per query

# --- 5. LANGGRAPH SETUP ---
class KBState(TypedDict):
    kb_text: str        # kept for compatibility; unused after RAG index is built
    retriever: Any      # LangChain retriever built from KB chunks
    prompts: Dict[str, Any]
    outputs: Dict[str, Any]
    prompts_used: Dict[str, Any]

llm = ChatOllama(model=ollama_model, temperature=ollama_model_temperature, format="json", base_url=OLLAMA_BASE_URL)

def save_json(path: str, data: Dict):
    os.makedirs(os.path.dirname(path), exist_ok=True)
    with open(path, "w", encoding="utf-8") as f:
        json.dump(data, f, indent=2)

def run_llm_with_schema(system_prompt: str, user_prompt: str, schema: BaseModel):
    parser = JsonOutputParser(pydantic_object=schema)
    format_instructions = parser.get_format_instructions()
    full_system_prompt = f"{system_prompt}\n\n{format_instructions}"
    res = llm.invoke([
        SystemMessage(content=full_system_prompt), 
        HumanMessage(content=user_prompt)
    ])
    try:
        parsed_data = parser.parse(res.content)
        return parsed_data
    except Exception as e:
        print(f"Validation Error: {e}\nRaw Output: {res.content}")
        return {"error": "LLM failed Pydantic validation.", "raw": res.content}

def load_inputs(state: KBState):
    if os.path.exists(KB_PATH):
        with open(KB_PATH, "r", encoding="utf-8") as f:
            kb_text = f.read()
    else:
        kb_text = "Dummy knowledge base text."

    print("Building RAG index from KB...")
    splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=50)
    chunks = splitter.create_documents([kb_text])
    embeddings = OllamaEmbeddings(model=ollama_model, base_url=OLLAMA_BASE_URL)
    vectorstore = Chroma.from_documents(chunks, embeddings)
    state["retriever"] = vectorstore.as_retriever(search_kwargs={"k": RAG_TOP_K})
    state["kb_text"] = ""

    state["prompts"] = PROMPTS
    state["outputs"] = {}
    state["prompts_used"] = {}
    return state

def run_extraction(key: str):
    def node(state: KBState):
        prompt_block = state["prompts"][key]
        query = RAG_QUERIES.get(key, key)
        docs = state["retriever"].invoke(query)
        kb_context = "\n\n".join(doc.page_content for doc in docs)
        user_prompt = prompt_block["user"].replace("{kb}", kb_context)
        if key == "feature_goal_map":
            user_prompt = user_prompt.replace("{features}", FEATURES_STRING)
        result = run_llm_with_schema(prompt_block["system"], user_prompt, prompt_block["schema"])
        state["outputs"][key] = result
        state["prompts_used"][key] = {"system": prompt_block["system"], "user": user_prompt}
        return state
    return node

def save_outputs(state: KBState):
    for key, value in state["outputs"].items():
        save_json(f"./output/{key}.json", value)
        save_json(f"../iteration_0_before_learning/{key}.json", value)
    return state


# --- 6. BUILD AND EXECUTE GRAPH ---
builder = StateGraph(KBState)
builder.add_node("load", load_inputs)

prompt_keys = list(PROMPTS.keys())
prev_node = "load"

for key in prompt_keys:
    current_node = f"extract_{key}"
    builder.add_node(current_node, run_extraction(key))
    builder.add_edge(prev_node, current_node)
    prev_node = current_node

builder.add_node("save", save_outputs)
builder.add_edge(prev_node, "save")
builder.add_edge("save", END)
builder.set_entry_point("load")

graph = builder.compile()

if __name__ == "__main__":
    print("Starting extraction pipeline with updated Pydantic schemas...")
    final_state = graph.invoke({"kb_text": "", "retriever": None, "prompts": {}, "outputs": {}, "prompts_used": {}})
    print("Pipeline complete. Check the output folders.")
# Out:
# Starting extraction pipeline with updated Pydantic schemas...
# Building RAG index from KB...
# Pipeline complete. Check the output folders.

# %% [markdown]
# # Missing data handeling

# %%
encoded_user_csv_path = "./input/users.csv"
df = pd.read_csv(encoded_user_csv_path)

numeric_cols = df.select_dtypes(include="number").columns
df[numeric_cols] = df[numeric_cols].fillna(df[numeric_cols].mean())

df.to_csv("./output/users_imputed.csv", index=False)

# %% [markdown]
# # Generating Propensity and Activeness scores

# %%
df = pd.read_csv("./output/users_imputed.csv")

# %%
gamification_score = 0.7 * df['streak_current'] + 0.3 * df['coins_balance']
mu = gamification_score.mean()
sigma = gamification_score.std()
df['gamification_propensity'] = 1 / (1 + np.exp(-(gamification_score - mu) / sigma))
df.head(1)
# Out:
#   user_id lifecycle_stage  days_since_signup age_band region  \
# 0    US_1            paid                119    25-34  tier2
#
#    sessions_last_7d  exercises_completed_7d  streak_current  coins_balance  \
# 0                 5                      16              22          453.0
#
#    feature_ai_tutor_used  feature_leaderboard_viewed  \
# 0                  False                       False
#
#    feature_progress_checked  preferred_hour  notif_open_rate_30d  \
# 0                      True               7                0.304
#
#    motivation_score  gamification_propensity
# 0              0.65                 0.845197

# %%
ai_tutor_score = 10 * df['feature_ai_tutor_used'] + 1.5 * df['exercises_completed_7d']
mu = ai_tutor_score.mean()
sigma = ai_tutor_score.std()
df['ai_tutor_propensity'] = 1 / (1 + np.exp(-(ai_tutor_score - mu) / sigma))
df.head(1)
# Out:
#   user_id lifecycle_stage  days_since_signup age_band region  \
# 0    US_1            paid                119    25-34  tier2
#
#    sessions_last_7d  exercises_completed_7d  streak_current  coins_balance  \
# 0                 5                      16              22          453.0
#
#    feature_ai_tutor_used  feature_leaderboard_viewed  \
# 0                  False                       False
#
#    feature_progress_checked  preferred_hour  notif_open_rate_30d  \
# 0                      True               7                0.304
#
#    motivation_score  gamification_propensity  ai_tutor_propensity
# 0              0.65                 0.845197             0.736033

# %%
leaderboard_score = 10 * df['feature_leaderboard_viewed'] + 5 * df['motivation_score']
mu = leaderboard_score.mean()
sigma = leaderboard_score.std()
df['leaderboard_propensity'] = 1 / (1 + np.exp(-(leaderboard_score - mu) / sigma))

df.head(1)
# Out:
#   user_id lifecycle_stage  days_since_signup age_band region  \
# 0    US_1            paid                119    25-34  tier2
#
#    sessions_last_7d  exercises_completed_7d  streak_current  coins_balance  \
# 0                 5                      16              22          453.0
#
#    feature_ai_tutor_used  feature_leaderboard_viewed  \
# 0                  False                       False
#
#    feature_progress_checked  preferred_hour  notif_open_rate_30d  \
# 0                      True               7                0.304
#
#    motivation_score  gamification_propensity  ai_tutor_propensity  \
# 0              0.65                 0.845197             0.736033
#
#    leaderboard_propensity
# 0                0.269036

# %%
from sklearn.decomposition import PCA

cols = ['sessions_last_7d', 'exercises_completed_7d', 'streak_current', 'notif_open_rate_30d', 'motivation_score']
standardized = pd.DataFrame()
for col in cols:
    standardized[col] = (df[col] - df[col].mean()) / df[col].std()

pca = PCA(n_components=1)
pca.fit(standardized)
weights = {col: pca.components_[0][i] for i, col in enumerate(cols)}

pc1_raw = sum(weights[col] * standardized[col] for col in cols)
pc1_min = pc1_raw.min()
pc1_max = pc1_raw.max()
df['activation_score'] = (pc1_raw - pc1_min) / (pc1_max - pc1_min)

df.head(1)
# Out:
#   user_id lifecycle_stage  days_since_signup age_band region  \
# 0    US_1            paid                119    25-34  tier2
#
#    sessions_last_7d  exercises_completed_7d  streak_current  coins_balance  \
# 0                 5                      16              22          453.0
#
#    feature_ai_tutor_used  feature_leaderboard_viewed  \
# 0                  False                       False
#
#    feature_progress_checked  preferred_hour  notif_open_rate_30d  \
# 0                      True               7                0.304
#
#    motivation_score  gamification_propensity  ai_tutor_propensity  \
# 0              0.65                 0.845197             0.736033
#
#    leaderboard_propensity  activation_score
# 0                0.269036          0.676695

# %%
df.to_csv("./output/users_propensity_generated.csv", index=False)

# %% [markdown]
# # Segmenting users

# %%
df = pd.read_csv("./output/users_propensity_generated.csv")

df['dominant_propensity'] = df[['gamification_propensity', 'ai_tutor_propensity', 'leaderboard_propensity']].idxmax(axis=1)
df['dominant_propensity'] = df['dominant_propensity'].str.replace('_propensity', '')

def get_activation_level(score):
    if score > 0.7:
        return 'High'
    elif score >= 0.4:
        return 'Medium'
    else:
        return 'Low'

df['activation_level'] = df['activation_score'].apply(get_activation_level)

segment_map = {
    ('gamification', 'High'): ('S1', 'Streak Champions'),
    ('ai_tutor', 'High'): ('S2', 'Power Learners'),
    ('leaderboard', 'High'): ('S3', 'Top Competitors'),
    ('gamification', 'Medium'): ('S4', 'Coin Collectors'),
    ('ai_tutor', 'Medium'): ('S5', 'Steady Students'),
    ('leaderboard', 'Medium'): ('S6', 'Social Observers'),
    ('gamification', 'Low'): ('S7', 'Fading Players'),
    ('ai_tutor', 'Low'): ('S8', 'Stuck Users'),
    ('leaderboard', 'Low'): ('S9', 'Disconnected'),
}

df[['segment_id', 'segment_name']] = df.apply(
    lambda row: pd.Series(segment_map[(row['dominant_propensity'], row['activation_level'])]),
    axis=1
)

df.to_csv("./output/users_segmented.csv", index=False)
df.to_csv("../iteration_0_before_learning/user_segments.csv", index=False)

# %% [markdown]
# # Assigning Goals , Sub-Goals for ech segment * lifecycle stage

# %%
import json, os
import pandas as pd
from typing import TypedDict, Dict, Any
from langchain_core.messages import SystemMessage, HumanMessage
from langgraph.graph import StateGraph, END

def run_llm(system_prompt: str, user_prompt: str):
    res = llm.invoke([SystemMessage(content=system_prompt), HumanMessage(content=user_prompt)])
    try: return json.loads(res.content)
    except json.JSONDecodeError: return {"raw_response": res.content}

# --- 1. Generate Segment × Lifecycle Stage Goals ---
df_segments = pd.read_csv("./output/users_segmented.csv")
feature_goals = load_json("./output/feature_goal_map.json")

lifecycle_context = {
    "trial": {"description": "Early Stage - Building Habits", "goal_modifier": "rapid adoption & habit formation", "focus": "Quick wins and onboarding"},
    "paid": {"description": "Engaged - Maximizing Value", "goal_modifier": "deepening engagement & retention", "focus": "Sustained usage and progression"},
    "churned": {"description": "At-Risk - Re-activation Needed", "goal_modifier": "re-engagement & recovering lost habits", "focus": "Breaking inactivity cycle"},
    "inactive": {"description": "Dormant - Win-Back Campaign", "goal_modifier": "compelling return value proposition", "focus": "Removing friction to return"},
}

feature_goal_map = {
    ptype: {"primary_goal": f"Increase {ptype} engagement", "sub_goals": [f"Drive {ptype} feature usage", f"Improve {ptype} adoption metrics"], "progression_goals": [f"Track daily {ptype} metrics"]}
    for ptype in ["gamification", "ai_tutor", "leaderboard"]
}

segments = sorted(df_segments['segment_id'].unique().tolist())
stages = df_segments['lifecycle_stage'].unique().tolist()
available_stages = (stages + [s for s in ["trial", "paid", "churned", "inactive"] if s not in stages])[:4]

segment_lifecycle_goals = {"combinations": []}
for _, row in df_segments.drop_duplicates(subset=['segment_id']).iterrows():
    base_goals = feature_goal_map.get(row['dominant_propensity'], {})
    
    for stage in available_stages:
        lc_info = lifecycle_context.get(stage, {})
        segment_lifecycle_goals["combinations"].append({
            "combination_id": f"{row['segment_id']}_{stage}",
            "segment_id": row['segment_id'], "segment_name": row['segment_name'],
            "lifecycle_stage": stage, "lifecycle_description": lc_info.get("description", ""),
            "dominant_propensity": row['dominant_propensity'], "activation_level": row['activation_level'],
            "primary_goal": f"{base_goals.get('primary_goal', 'Engagement')} • {lc_info.get('goal_modifier', 'optimize engagement')}",
            "sub_goals": [f"{sg} ({stage.title()} context: {lc_info.get('focus', 'engagement')})" for sg in base_goals.get('sub_goals', [])],
            "day_on_day_progression_goals": [f"{pg} • Track in {stage} phase" for pg in base_goals.get('progression_goals', [])],
            "lifecycle_context": {"stage": stage, **lc_info}
        })

df_goals = pd.DataFrame(segment_lifecycle_goals["combinations"])
df_goals.to_csv("./output/segment_lifecycle_goals.csv", index=False)
df_goals.to_csv("../iteration_0_before_learning/segment_goals.csv", index=False)

# --- 2. Build Segment Profiles (Optimized with Pandas GroupBy) ---
aggs = {
    'segment_name': 'first', 'dominant_propensity': lambda x: x.mode()[0], 'activation_level': lambda x: x.mode()[0],
    'gamification_propensity': 'mean', 'ai_tutor_propensity': 'mean', 'leaderboard_propensity': 'mean', 
    'activation_score': 'mean', 'user_id': 'count'
}
segment_profiles = df_segments.groupby('segment_id').agg(aggs).rename(columns={
    'gamification_propensity': 'avg_gamification', 'ai_tutor_propensity': 'avg_ai_tutor',
    'leaderboard_propensity': 'avg_leaderboard', 'activation_score': 'avg_activation', 'user_id': 'user_count'
}).reset_index().set_index('segment_id', drop=False).to_dict('index')

# --- 3. Setup & Execute Theme Engine ---
class ThemeEngineState(TypedDict):
    segment_profiles: Dict[str, Any]
    tone_hooks: Dict[str, Any]
    outputs: Dict[str, Any]

def load_theme_inputs(state: ThemeEngineState):
    state["segment_profiles"] = segment_profiles
    try:
        hooks = load_json("./output/allowed_tone_hook_matrix.json").get("hook_taxonomy", [])
        state["tone_hooks"] = {"octolysis_hook_mapping": {h.get("hook_name", h.get("name", str(h))): h.get("description", "") for h in hooks if isinstance(h, dict)}}
        if not state["tone_hooks"]["octolysis_hook_mapping"]: raise ValueError
    except Exception:
        state["tone_hooks"] = {"octolysis_hook_mapping": {"Epic Meaning": "Larger purpose", "Accomplishment": "Progress", "Empowerment": "Creativity", "Social Influence": "Relatedness", "Scarcity": "Exclusivity", "Unpredictability": "Surprises", "Loss Avoidance": "FOMO"}}
    return state

def extract_segment_themes(state: ThemeEngineState):
    prompts = load_json(PROMPTS_PATH)["segment_themes"]
    hooks_str = json.dumps(state["tone_hooks"]["octolysis_hook_mapping"], indent=2)
    theme_results = []

    for sid, prof in state["segment_profiles"].items():
        user_prompt = prompts["user"]
        # Safe string replacements
        replacements = {
            "{segment_id}": sid, "{segment_name}": prof['segment_name'], "{dominant_propensity}": prof['dominant_propensity'],
            "{activation_level}": prof['activation_level'], "{avg_gamification}": f"{prof['avg_gamification']:.3f}",
            "{avg_ai_tutor}": f"{prof['avg_ai_tutor']:.3f}", "{avg_leaderboard}": f"{prof['avg_leaderboard']:.3f}",
            "{avg_activation}": f"{prof['avg_activation']:.3f}", "{user_count}": str(prof['user_count']), "{tone_hooks_json}": hooks_str
        }
        for k, v in replacements.items(): user_prompt = user_prompt.replace(k, v)
        
        try:
            theme_results.append(run_llm(prompts["system"], user_prompt))
            print(f"✓ Processed {sid}")
        except Exception as e:
            print(f"✗ Error {sid}: {e}")

    state["outputs"] = {"segment_themes": {"segments": theme_results, "total_segments": len(theme_results)}}
    return state

def save_theme_outputs(state: ThemeEngineState):
    save_json("./output/segment_themes.json", state["outputs"]["segment_themes"])
    return state

theme_builder = StateGraph(ThemeEngineState)
for node in [load_theme_inputs, extract_segment_themes, save_theme_outputs]: theme_builder.add_node(node.__name__, node)
theme_builder.add_edge("load_theme_inputs", "extract_segment_themes")
theme_builder.add_edge("extract_segment_themes", "save_theme_outputs")
theme_builder.add_edge("save_theme_outputs", END)
theme_builder.set_entry_point("load_theme_inputs")

theme_builder.compile().invoke({"segment_profiles": {}, "tone_hooks": {}, "outputs": {}})
# Out:
# ✓ Processed S1
# ✓ Processed S2
# ✓ Processed S3
# ✓ Processed S4
# ✓ Processed S5
# ✓ Processed S6
# ✓ Processed S7
# ✓ Processed S8
# ✓ Processed S9
# {'segment_profiles': {'S1': {'segment_id': 'S1',
#    'segment_name': 'Streak Champions',
#    'dominant_propensity': 'gamification',
#    'activation_level': 'High',
#    'avg_gamification': 0.8439428524973793,
#    'avg_ai_tutor': 0.7827800002005074,
#    'avg_leaderboard': 0.7046352669946109,
#    'avg_activation': 0.8119243924809343,
#    'user_count': 5},
#   'S2': {'segment_id': 'S2',
#    'segment_name': 'Power Learners',
#    'dominant_propensity': 'ai_tutor',
#    'activation_level': 'High',
#    'avg_gamification': 0.7013564395844473,
#    'avg_ai_tutor': 0.7752483194177304,
#    'avg_leaderboard': 0.5664003574361666,
#    'avg_activation': 0.7579272040554187,
#    'user_count': 6},
#   'S3': {'segment_id': 'S3',
#    'segment_name': 'Top Competitors',
#    'dominant_propensity': 'leaderboard',
#    'activation_level': 'High',
#    'avg_gamification': 0.6637823078473643,
#    'avg_ai_tutor': 0.5643028548264094,
#    'avg_leaderboard': 0.714977560675781,
#    'avg_activation': 0.7716865115519909,
#    'user_count': 3},
#   'S4': {'segment_id': 'S4',
#    'segment_name': 'Coin Collectors',
#    'dominant_propensity': 'gamification',
#    'activation_level': 'Medium',
#    'avg_gamification': 0.7777501457876828,
#    'avg_ai_tutor': 0.6744183685663774,
#    'avg_leaderboard': 0.5192154604672703,
#    'avg_activation': 0.6395921507780089,
#    'user_count': 5},
#   'S5': {'segment_id': 'S5',
#    'segment_name': 'Steady Students',
#    'dominant_propensity': 'ai_tutor',
#    'activation_level': 'Medium',
#    'avg_gamification': 0.46207320187997536,
#    'avg_ai_tutor': 0.5370877400505545,
#    'avg_leaderboard': 0.3876610662329979,
#    'avg_activation': 0.5557873695189273,
#    'user_count': 11},
#   'S6': {'segment_id': 'S6',
#    'segment_name': 'Social Observers',
#    'dominant_propensity': 'leaderboard',
#    'activation_level': 'Medium',
#    'avg_gamification': 0.4033148048925372,
#    'avg_ai_tutor': 0.4464827080448673,
#    'avg_leaderboard': 0.7028073794712738,
#    'avg_activation': 0.5421379733879451,
#    'user_count': 14},
#   'S7': {'segment_id': 'S7',
#    'segment_name': 'Fading Players',
#    'dominant_propensity': 'gamification',
#    'activation_level': 'Low',
#    'avg_gamification': 0.2731537749711919,
#    'avg_ai_tutor': 0.2372510775201605,
#    'avg_leaderboard': 0.2035742347731059,
#    'avg_activation': 0.07248616214811147,
#    'user_count': 12},
#   'S8': {'segment_id': 'S8',
#    'segment_name': 'Stuck Users',
#    'dominant_propensity': 'ai_tutor',
#    'activation_level': 'Low',
#    'avg_gamification': 0.2607533250912449,
#    'avg_ai_tutor': 0.4317232643999563,
#    'avg_leaderboard': 0.2088032563553157,
#    'avg_activation': 0.0672246482682596,
#    'user_count': 1},
#   'S9': {'segment_id': 'S9',
#    'segment_name': 'Disconnected',
#    'dominant_propensity': 'leaderboard',
#    'activation_level': 'Low',
#    'avg_gamification': 0.34535627658252327,
#    'avg_ai_tutor': 0.2671011342486592,
#    'avg_leaderboard': 0.6140809072960529,
#    'avg_activation': 0.144706916528329,
#    'user_count': 4}},
#  'tone_hooks': {'octolysis_hook_mapping': {'Paid (D8–30)': 'Value realization',
#    'Retention (D31+)': 'Identity formation',
#    'Churned / Inactive': 'Re-activation'}},
#  'outputs': {'segment_themes': {'segments': [{'segment_id': 'S1',
#      'segment_name': 'Streak Champions',
#      'octolysis_themes': [{'core_drive': 'Accomplishment',
#        'relevance_score': 0.83,
#        'reasoning': 'High gamification propensity and activation level align with mastery of skills and progress tracking'},
#       {'core_drive': 'Epic Meaning',
#        'relevance_score': 0.42,
#        'reasoning': 'Moderate AI tutor propensity and retention product hook hint at connection to something bigger'},
#       {'core_drive': 'Ownership',
#        'relevance_score': 0.19,
#        'reasoning': 'Low ownership propensity and no clear product hook for building possessions'},
#       {'core_drive': 'Social Influence',
#        'relevance_score': 0.56,
#        'reasoning': 'Moderate leaderboard propensity and activation level suggest connection to community and status'},
#       {'core_drive': 'Scarcity',
#        'relevance_score': 0.11,
#        'reasoning': 'Low scarcity propensity and no clear product hook for limited access'},
#       {'core_drive': 'Unpredictability',
#        'relevance_score': 0.0,
#        'reasoning': 'No clear product hook or propensity for curiosity, randomness, or novelty'},
#       {'core_drive': 'Loss Avoidance',
#        'relevance_score': 0.65,
#        'reasoning': 'High retention product hook and activation level align with fear of losing progress and habit streaks'},
#       {'core_drive': 'Empowerment',
#        'relevance_score': 0.0,
#        'reasoning': 'No clear product hook or propensity for creative control, making choices'}]},
#     {'segment_id': 'S2',
#      'segment_name': 'Power Learners',
#      'octolysis_themes': [{'core_drive': 'Accomplishment',
#        'relevance_score': 0.83,
#        'reasoning': 'High activation level and ai_tutor propensity indicate a strong desire for skill mastery and progress'},
#       {'core_drive': 'Epic Meaning',
#        'relevance_score': 0.42,
#        'reasoning': 'Moderate activation level and no explicit connection to community or status'},
#       {'core_drive': 'Empowerment',
#        'relevance_score': 0.11,
#        'reasoning': 'Low activation level and no clear indication of creative control or choice'},
#       {'core_drive': 'Ownership',
#        'relevance_score': 0.0,
#        'reasoning': 'No clear indication of building possessions or investing time/effort'},
#       {'core_drive': 'Social Influence',
#        'relevance_score': 0.0,
#        'reasoning': 'No clear indication of connection to community or status'},
#       {'core_drive': 'Scarcity',
#        'relevance_score': 0.0,
#        'reasoning': 'No clear indication of fear of missing out or limited access'},
#       {'core_drive': 'Unpredictability',
#        'relevance_score': 0.0,
#        'reasoning': 'No clear indication of curiosity or randomness'},
#       {'core_drive': 'Loss Avoidance',
#        'relevance_score': 0.56,
#        'reasoning': 'Moderate activation level and product hook for re-activation'}]},
#     {'segment_id': 'S3',
#      'segment_name': 'Top Competitors',
#      'octolysis_themes': [{'core_drive': 'Accomplishment',
#        'relevance_score': 0.83,
#        'reasoning': 'High leaderboard propensity and activation level indicate a strong desire for progress and mastery'},
#       {'core_drive': 'Social Influence',
#        'relevance_score': 0.72,
#        'reasoning': 'Top competitors are highly activated and have a strong propensity for gamification, suggesting a desire for connection and status'},
#       {'core_drive': 'Epic Meaning',
#        'relevance_score': 0.56,
#        'reasoning': "While not dominant, the segment's high activation level and average AI tutor propensity suggest a desire for meaning and purpose"},
#       {'core_drive': 'Ownership',
#        'relevance_score': 0.45,
#        'reasoning': 'Moderate propensity for AI tutors and activation level indicate a desire for building and investing in something'},
#       {'core_drive': 'Scarcity',
#        'relevance_score': 0.38,
#        'reasoning': 'Low but present activation level and average leaderboard propensity suggest a fear of missing out or limited access'},
#       {'core_drive': 'Unpredictability',
#        'relevance_score': 0.23,
#        'reasoning': 'Low activation level and average AI tutor propensity indicate a lack of curiosity or novelty-seeking'},
#       {'core_drive': 'Loss Avoidance',
#        'relevance_score': 0.17,
#        'reasoning': 'Low activation level and average leaderboard propensity suggest a low fear of losing progress or habit streaks'},
#       {'core_drive': 'Empowerment',
#        'relevance_score': 0.12,
#        'reasoning': 'Low activation level and average AI tutor propensity indicate a lack of creative control or choice'}]},
#     {'segment_id': 'S4',
#      'segment_name': 'Coin Collectors',
#      'octolysis_themes': [{'core_drive': 'Accomplishment',
#        'relevance_score': 0.83,
#        'reasoning': 'Dominant propensity for gamification and activation level of Medium align with Accomplishment core drive'},
#       {'core_drive': 'Ownership',
#        'relevance_score': 0.72,
#        'reasoning': "User's interest in collecting coins and building possessions aligns with Ownership core drive"},
#       {'core_drive': 'Social Influence',
#        'relevance_score': 0.56,
#        'reasoning': "User's activation level and interest in community status align with Social Influence core drive"},
#       {'core_drive': 'Epic Meaning',
#        'relevance_score': 0.41,
#        'reasoning': "User's interest in collecting rare coins and feeling part of a community aligns with Epic Meaning core drive"},
#       {'core_drive': 'Scarcity',
#        'relevance_score': 0.29,
#        'reasoning': "User's activation level and interest in limited access align with Scarcity core drive"},
#       {'core_drive': 'Unpredictability',
#        'relevance_score': 0.19,
#        'reasoning': "User's interest in collecting rare coins and novelty aligns with Unpredictability core drive"},
#       {'core_drive': 'Loss Avoidance',
#        'relevance_score': 0.11,
#        'reasoning': "User's activation level and interest in re-activation align with Loss Avoidance core drive"},
#       {'core_drive': 'Empowerment',
#        'relevance_score': 0.05,
#        'reasoning': "User's interest in collecting coins does not strongly align with Empowerment core drive"}]},
#     {'segment_id': 'S5',
#      'segment_name': 'Steady Students',
#      'octolysis_themes': [{'core_drive': 'Accomplishment',
#        'relevance_score': 0.83,
#        'reasoning': 'Dominant propensity: ai_tutor; Activation Level: Medium; Product Context: Value realization'},
#       {'core_drive': 'Empowerment',
#        'relevance_score': 0.42,
#        'reasoning': 'Activation Level: Medium; Product Context: Value realization'},
#       {'core_drive': 'Ownership',
#        'relevance_score': 0.19,
#        'reasoning': 'Product Context: Value realization'},
#       {'core_drive': 'Social Influence',
#        'relevance_score': 0.56,
#        'reasoning': 'Activation Level: Medium; Product Context: Value realization'},
#       {'core_drive': 'Scarcity',
#        'relevance_score': 0.11,
#        'reasoning': 'Product Context: Value realization'},
#       {'core_drive': 'Unpredictability',
#        'relevance_score': 0.0,
#        'reasoning': 'No relevance'},
#       {'core_drive': 'Loss Avoidance',
#        'relevance_score': 0.3,
#        'reasoning': 'Activation Level: Medium; Product Context: Value realization'},
#       {'core_drive': 'Epic Meaning',
#        'relevance_score': 0.0,
#        'reasoning': 'No relevance'}]},
#     {'segment_id': 'S6',
#      'segment_name': 'Social Observers',
#      'octolysis_themes': [{'core_drive': 'Social Influence',
#        'relevance_score': 0.83,
#        'reasoning': 'High leaderboard propensity and activation level indicate a desire for social comparison and community connection'},
#       {'core_drive': 'Accomplishment',
#        'relevance_score': 0.56,
#        'reasoning': 'Moderate AI tutor propensity suggests a desire for skill mastery and progress'},
#       {'core_drive': 'Epic Meaning',
#        'relevance_score': 0.42,
#        'reasoning': 'Low epic meaning propensity, but medium activation level indicates a desire for connection to something bigger'},
#       {'core_drive': 'Ownership',
#        'relevance_score': 0.19,
#        'reasoning': 'Low ownership propensity, but moderate activation level suggests a desire for building possessions'},
#       {'core_drive': 'Scarcity',
#        'relevance_score': 0.11,
#        'reasoning': 'Low scarcity propensity, but high activation level indicates a fear of missing out'},
#       {'core_drive': 'Unpredictability',
#        'relevance_score': 0.05,
#        'reasoning': 'Low unpredictability propensity, but medium activation level suggests a desire for novelty'},
#       {'core_drive': 'Loss Avoidance',
#        'relevance_score': 0.03,
#        'reasoning': 'Low loss avoidance propensity, but high activation level indicates a fear of losing progress'},
#       {'core_drive': 'Empowerment',
#        'relevance_score': 0.01,
#        'reasoning': 'Low empowerment propensity, but low activation level suggests a lack of creative control'}]},
#     {'segment_id': 'S7',
#      'segment_name': 'Fading Players',
#      'octolysis_themes': [{'core_drive': 'Accomplishment',
#        'relevance_score': 0.05,
#        'reasoning': 'Low gamification propensity and activation level indicate a lack of progress and mastery'},
#       {'core_drive': 'Loss Avoidance',
#        'relevance_score': 0.3,
#        'reasoning': 'Fading players are likely to fear losing progress and habit streaks'},
#       {'core_drive': 'Social Influence',
#        'relevance_score': 0.1,
#        'reasoning': 'Low social influence propensity suggests a lack of connection to community and status'},
#       {'core_drive': 'Unpredictability',
#        'relevance_score': 0.05,
#        'reasoning': 'Low activation level and lack of product hooks indicate a need for novelty and randomness'},
#       {'core_drive': 'Epic Meaning',
#        'relevance_score': 0.05,
#        'reasoning': 'Low activation level and lack of product hooks indicate a lack of connection to something bigger'},
#       {'core_drive': 'Empowerment',
#        'relevance_score': 0.0,
#        'reasoning': 'Low activation level and lack of product hooks indicate a lack of creative control and choices'},
#       {'core_drive': 'Ownership',
#        'relevance_score': 0.0,
#        'reasoning': 'Low activation level and lack of product hooks indicate a lack of building possessions and investing time/effort'},
#       {'core_drive': 'Scarcity',
#        'relevance_score': 0.0,
#        'reasoning': 'Low activation level and lack of product hooks indicate a lack of fear of missing out and limited access'}]},
#     {'segment_id': 'S8',
#      'segment_name': 'Stuck Users',
#      'octolysis_themes': [{'core_drive': 'Accomplishment',
#        'relevance_score': 0.23,
#        'reasoning': 'Low avg_gamification and avg_ai_tutor propensities indicate a lack of progress and skill mastery'},
#       {'core_drive': 'Loss Avoidance',
#        'relevance_score': 0.51,
#        'reasoning': 'Low avg_activation and high churn/inactive rates suggest fear of losing progress and habit streaks'},
#       {'core_drive': 'Social Influence',
#        'relevance_score': 0.14,
#        'reasoning': 'Low avg_leaderboard propensity indicates a lack of connection to community and status'},
#       {'core_drive': 'Unpredictability',
#        'relevance_score': 0.01,
#        'reasoning': 'Low avg_activation and no product hooks indicate a lack of novelty and randomness'},
#       {'core_drive': 'Epic Meaning',
#        'relevance_score': 0.05,
#        'reasoning': 'Low avg_gamification and avg_ai_tutor propensities indicate a lack of connection to something bigger than oneself'},
#       {'core_drive': 'Empowerment',
#        'relevance_score': 0.0,
#        'reasoning': 'Low avg_gamification and avg_ai_tutor propensities indicate a lack of creative control and choices'},
#       {'core_drive': 'Ownership',
#        'relevance_score': 0.0,
#        'reasoning': 'Low avg_gamification and avg_ai_tutor propensities indicate a lack of building possessions and investing time/effort'},
#       {'core_drive': 'Scarcity',
#        'relevance_score': 0.0,
#        'reasoning': 'Low avg_activation and no product hooks indicate a lack of fear of missing out and limited access'}]},
#     {'segment_id': 'S9',
#      'segment_name': 'Disconnected',
#      'octolysis_themes': [{'core_drive': 'Accomplishment',
#        'relevance_score': 0.05,
#        'reasoning': 'Low activation level and average AI tutor propensity indicate a lack of progress or skill mastery'},
#       {'core_drive': 'Social Influence',
#        'relevance_score': 0.15,
#        'reasoning': 'Dominant propensity for leaderboard and average activation score suggest a desire for connection and status'},
#       {'core_drive': 'Scarcity',
#        'relevance_score': 0.1,
#        'reasoning': 'Low activation level and average leaderboard propensity indicate a fear of missing out'},
#       {'core_drive': 'Unpredictability',
#        'relevance_score': 0.05,
#        'reasoning': 'Low activation level and lack of engagement suggest a desire for novelty and randomness'},
#       {'core_drive': 'Loss Avoidance',
#        'relevance_score': 0.2,
#        'reasoning': 'Low activation score and average leaderboard propensity indicate a fear of losing progress and habit streaks'},
#       {'core_drive': 'Epic Meaning',
#        'relevance_score': 0.05,
#        'reasoning': 'Low activation level and lack of engagement suggest a lack of connection to a larger purpose'},
#       {'core_drive': 'Empowerment',
#        'relevance_score': 0.0,
#        'reasoning': 'Low activation level and lack of engagement indicate a lack of creative control and choice'},
#       {'core_drive': 'Ownership',
#        'relevance_score': 0.0,
#        'reasoning': 'Low activation level and lack of engagement suggest a lack of investment in possessions or time/effort'}]}],
#    'total_segments': 9}}}
